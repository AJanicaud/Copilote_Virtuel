# %%
import rasterio
data = rasterio.open("Downloads/OACI/OACI_23_L93_E100.jp2")

# Les coordonnées des quatre coins de la carte en Lambert 93
# (L93 dans le nom de fichier => projection Lambert93)
# https://epsg.io/2154
data.bounds
# Out:
# BoundingBox(left=470000.0, bottom=5950000.0, right=870000.0, top=6350000.0)

# %%
from PIL import Image
import numpy as np

# Chargement du fond de carte, c'est un peu long
fname = 'Downloads/OACI/OACI_23_L93_E100.jp2'
image = Image.open(fname)
arr = np.asarray(image)

# %%
import pandas as pd

# la trajectoire
traj_file = "Downloads/Trajectoire Lasbordes-Montauban.txt"
with open(traj_file) as fh:
    traj = eval("".join(p.strip() for p in fh.readlines()))
    traj = pd.DataFrame.from_records(traj, columns=['latitude', 'longitude'])

traj.head()
# Out:
#     latitude  longitude
# 0  43.588000   1.499000
# 1  43.588367   1.498899
# 2  43.588735   1.498797
# 3  43.589102   1.498696
# 4  43.589470   1.498595

# %%
from traffic.core import Flight
from datetime import datetime

# on peut écrire Flight(traj) et le plot fonctionnerait
# mais la bibliothèque est contente
# si on a une colonne altitude et une colonne timestamp
now = datetime.now()
f = Flight(traj.assign(altitude=0, timestamp=now))

# %%
# plus il y a de colonnes, plus l'affichage est riche...
f
# Out:
#        latitude  longitude  altitude                  timestamp
# 0     43.588000   1.499000         0 2018-11-12 13:58:48.650059
# 1     43.588367   1.498899         0 2018-11-12 13:58:48.650059
# 2     43.588735   1.498797         0 2018-11-12 13:58:48.650059
# 3     43.589102   1.498696         0 2018-11-12 13:58:48.650059
# 4     43.589470   1.498595         0 2018-11-12 13:58:48.650059
# 5     43.589837   1.498493         0 2018-11-12 13:58:48.650059
# 6     43.590205   1.498392         0 2018-11-12 13:58:48.650059
# 7     43.590572   1.498290         0 2018-11-12 13:58:48.650059
# 8     43.590940   1.498189         0 2018-11-12 13:58:48.650059
# 9     43.591307   1.498088         0 2018-11-12 13:58:48.650059
# 10    43.591675   1.497986         0 2018-11-12 13:58:48.650059
# 11    43.592042   1.497885         0 2018-11-12 13:58:48.650059
# 12    43.592409   1.497784         0 2018-11-12 13:58:48.650059
# 13    43.592777   1.497682         0 2018-11-12 13:58:48.650059
# 14    43.593144   1.497581         0 2018-11-12 13:58:48.650059
# 15    43.593512   1.497480         0 2018-11-12 13:58:48.650059
# 16    43.593879   1.497378         0 2018-11-12 13:58:48.650059
# 17    43.594247   1.497277         0 2018-11-12 13:58:48.650059
# 18    43.594614   1.497175         0 2018-11-12 13:58:48.650059
# 19    43.594982   1.497074         0 2018-11-12 13:58:48.650059
# 20    43.595349   1.496973         0 2018-11-12 13:58:48.650059
# 21    43.595717   1.496871         0 2018-11-12 13:58:48.650059
# 22    43.596084   1.496770         0 2018-11-12 13:58:48.650059
# 23    43.596451   1.496668         0 2018-11-12 13:58:48.650059
# 24    43.596819   1.496567         0 2018-11-12 13:58:48.650059
# 25    43.597186   1.496466         0 2018-11-12 13:58:48.650059
# 26    43.597554   1.496364         0 2018-11-12 13:58:48.650059
# 27    43.597921   1.496263         0 2018-11-12 13:58:48.650059
# 28    43.598289   1.496162         0 2018-11-12 13:58:48.650059
# 29    43.598656   1.496060         0 2018-11-12 13:58:48.650059
# ...         ...        ...       ...                        ...
# 1166  44.016392   1.379970         0 2018-11-12 13:58:48.650059
# 1167  44.016759   1.379867         0 2018-11-12 13:58:48.650059
# 1168  44.017126   1.379764         0 2018-11-12 13:58:48.650059
# 1169  44.017494   1.379661         0 2018-11-12 13:58:48.650059
# 1170  44.017861   1.379559         0 2018-11-12 13:58:48.650059
# 1171  44.018228   1.379456         0 2018-11-12 13:58:48.650059
# 1172  44.018596   1.379353         0 2018-11-12 13:58:48.650059
# 1173  44.018963   1.379250         0 2018-11-12 13:58:48.650059
# 1174  44.019330   1.379147         0 2018-11-12 13:58:48.650059
# 1175  44.019698   1.379044         0 2018-11-12 13:58:48.650059
# 1176  44.020065   1.378942         0 2018-11-12 13:58:48.650059
# 1177  44.020432   1.378839         0 2018-11-12 13:58:48.650059
# 1178  44.020800   1.378736         0 2018-11-12 13:58:48.650059
# 1179  44.021167   1.378633         0 2018-11-12 13:58:48.650059
# 1180  44.021534   1.378530         0 2018-11-12 13:58:48.650059
# 1181  44.021902   1.378427         0 2018-11-12 13:58:48.650059
# 1182  44.022269   1.378325         0 2018-11-12 13:58:48.650059
# 1183  44.022637   1.378222         0 2018-11-12 13:58:48.650059
# 1184  44.023004   1.378119         0 2018-11-12 13:58:48.650059
# 1185  44.023371   1.378016         0 2018-11-12 13:58:48.650059
# 1186  44.023739   1.377913         0 2018-11-12 13:58:48.650059
# 1187  44.024106   1.377810         0 2018-11-12 13:58:48.650059
# 1188  44.024473   1.377707         0 2018-11-12 13:58:48.650059
# 1189  44.024841   1.377605         0 2018-11-12 13:58:48.650059
# 1190  44.025208   1.377502         0 2018-11-12 13:58:48.650059
# 1191  44.025575   1.377399         0 2018-11-12 13:58:48.650059
# 1192  44.025943   1.377296         0 2018-11-12 13:58:48.650059
# 1193  44.026310   1.377193         0 2018-11-12 13:58:48.650059
# 1194  44.026677   1.377090         0 2018-11-12 13:58:48.650059
# 1195  44.027000   1.377000         0 2018-11-12 13:58:48.650059
#
# [1196 rows x 4 columns]

# %%
data.bounds
# Out:
# BoundingBox(left=470000.0, bottom=5950000.0, right=870000.0, top=6350000.0)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from traffic.drawing import Lambert93
from traffic.data import airac

with plt.style.context('traffic'):
    fig, ax = plt.subplots(figsize=(15, 15), subplot_kw=dict(projection=Lambert93()))

    ax.imshow(  # fond de carte
        arr[::-1],
        extent=(
            data.bounds.left, data.bounds.right,
            data.bounds.bottom, data.bounds.top),
        alpha=.3  # transparence
    )
    
    # essayez différents extent
    ax.set_extent((1, 2, 43.5, 44))
    ax.set_extent(f.extent())

    # essayez différents paramètres, linestyle='dashed', linewidth=3 par exemple
    rep = f.plot(ax, color='red')
    
    fig.savefig("example.pdf")

# %%
# pour l'affichage interactif (hors notebook), on peut effacer les lignes,
# comme avec d'autres exemples qu'on peut trouver en ligne.
# ce qui sort du f.plot c'est la même chose que ce qui sort d'un plot classique
rep
